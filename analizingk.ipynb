# %% [markdown]
# <a href="https://colab.research.google.com/github/joxe22/joxpro/blob/Child_Branch/analizingk.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os
os.environ['KAGGLE_CONFIG_DIR'] = '/content/gdrive/MyDrive/descargas_kaggle'

# %%
# %cd /content/gdrive/MyDrive/descargas_kaggle
# Out:
# /content/gdrive/MyDrive/descargas_kaggle

# %%
# !ls
# Out:
# analizingk.ipynb  kaggle.json

# %%
# !kaggle datasets download -d moltean/fruits
# Out:
# ...
#  99% 1.28G/1.28G [00:11<00:00, 107MB/s]
# 100% 1.28G/1.28G [00:11<00:00, 120MB/s]

# %%
# !mkdir Train_fruits
# !mv fruits.zip Train_fruits

# %%
# %cd Train_fruits/
# Out:
# /content/gdrive/MyDrive/descargas_kaggle/Train_fruits

# %%
# !unzip fruits.zip
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/112_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/113_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/114_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/115_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/116_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/117_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/119_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/120_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/121_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/122_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/123_100.jpg
#   inflating: fruits-360_dataset/fruits-360/Training/Tomato 3/124_100.jpg
# ...

# %%
import cv2
from google.colab.patches import cv2_imshow
ing = cv2.imread('/content/gdrive/MyDrive/descargas_kaggle/Train_fruits/fruits-360_dataset/fruits-360/Test/Apple Braeburn/321_100.jpg')
cv2_imshow(ing)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FACAF8E16D0>

# %%
import cv2
from google.colab.patches import cv2_imshow
ing = cv2.imread('/content/gdrive/MyDrive/descargas_kaggle/Train_fruits/fruits-360_dataset/fruits-360/Test/Avocado/46_100.jpg')
cv2_imshow(ing)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FACA4209F40>

# %%
import cv2
from google.colab.patches import cv2_imshow
ing = cv2.imread('/content/gdrive/MyDrive/descargas_kaggle/Train_fruits/fruits-360_dataset/fruits-360/Test/Banana/102_100.jpg')
cv2_imshow(ing)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x7FACA4209DC0>
